# %% [markdown]
# # Generator File: GPT2-Medium

# %% [markdown]
# ## 1. Importing libraries and functions

# %%
try:
    print(gpt2_libraries_progress)
except NameError:
    # %run ./generation/generator_gpt2_libraries.ipynb

# %% [markdown]
# ## 2. Importing model

# %%
print("Loading model...")

# %%
# Import GPT2 pretrained model
from transformers import GPT2LMHeadModel
gpt2 = GPT2LMHeadModel.from_pretrained('gpt2-medium')

# %%
clear_output()
print("Function and Model now available for use:\n    gen_story(my_model=gpt2, seed, max_len)")

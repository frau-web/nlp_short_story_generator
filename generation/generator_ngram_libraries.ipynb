# %% [markdown]
# First we import the relevant files

# %%
import nltk, re, pprint
from nltk import word_tokenize
import os
import codecs
from IPython.display import clear_output

# %% [markdown]
# Google collab is missing many parts of nltk, so I download them manually here

# %%
nltk.download('punkt')
nltk.download('stopwords')
nltk.download('treebank')
nltk.download('gutenberg')
nltk.download('genesis')
nltk.download('inaugural')
nltk.download('nps_chat')
nltk.download('webtext')

# %%
clear_output()
ngram_libraries_progress = "n-gram libraries installed and loaded."
print(ngram_libraries_progress)

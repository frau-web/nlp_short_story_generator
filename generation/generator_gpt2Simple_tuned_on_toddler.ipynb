# %% [markdown]
# # Generator File: GPT2 Finetuning Library

# %% [markdown]
# ## 1. Importing libraries

# %%
try:
    print(gpt2_simple_libraries_progress)
except NameError:
    # %run ./generation/generator_gpt2_simple_libraries.ipynb

# %% [markdown]
# ## 2. Importing model

# %%
print("Importing model...")

# %%
#Create a temporary file structure and copy required file to mimic structure expected by copy_checkpoint_from_gdrive( )
# !mkdir "/content/drive/"
# !mkdir "/content/drive/My Drive/"
checkpoint_path = data_path +"/models/checkpoint_run1.tar"
# !cp $checkpoint_path "/content/drive/My Drive/"

# %%
#Relocate to folder where this model should live (the next step copies to the current directory)
# %cd "/content/simple/"

# %%
#Import model from checkpoint (from temporary folders to current directory)
gpt2_simple_library.copy_checkpoint_from_gdrive(run_name='run1')
sess_run1 = gpt2_simple_library.start_tf_sess()
gpt2_simple_library.load_gpt2(sess_run1, run_name='run1')

# %%
#Remove temporary files
# !rm "/content/drive/My Drive/checkpoint_run1.tar"
# !rmdir "/content/drive/My Drive"
# !rmdir "/content/drive"

# %%
  #Change back to the default directory of parent notebook
  # %cd $code_path

# %% [markdown]
# ## 3. Generating Text Function

# %%
def gen_story_gpt2_simple_tunedonT(seed, max_len):
  return gen_story_gpt2_simple(my_simple_session = sess_run1, my_run = 'run1', seed = seed, max_len = max_len)

# %%
clear_output()
print("Function and model loaded and available for use:\n    gen_story_gpt2_simple_tunedonT(seed, max_len)")
print("    *Based on GPT2-Small  | Tuned on input_stories_toddler.txt | Using gpt_2_simple library" )
